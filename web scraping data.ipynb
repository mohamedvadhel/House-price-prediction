Maison - Villa
#
#   Telephone Number             Price
# 0      41 30 60 60  prix indéterminé
# 1      36 68 43 68  prix indéterminé
# 2      41 87 75 49     1,200,000 MRU
# 3      41 87 75 49       700,000 MRU
# 4      27 82 81 31     5,500,000 MRU
# 5      27 82 81 31       750,000 MRU
# 6      27 82 81 31     1,200,000 MRU
# 7      31 31 30 57  prix indéterminé
# 8      41 44 77 83       320,000 MRU
# 9      41 44 77 83       340,000 MRU

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define the base URL of the real estate website
base_url = 'https://www.voursa.com/Index.cfm?PN={}&gct=3&gv=13'

# Set the number of pages to scrape (modify as per your requirement)
num_pages = 270

# Initialize empty lists to store the scraped data
surface = []
description = []
additional_info = []
telephone_numbers = []
prices = []

# Define the keywords to filter by
keywords = ['Maison', 'Bâtiment', 'Villa']

# Iterate over each page
for page in range(256, num_pages + 1):
    # Construct the URL for the current page
    url = base_url.format(page)

    # Send an HTTP GET request to the website and retrieve the HTML content
    response = requests.get(url)
    html_content = response.content

    # Create a BeautifulSoup object to parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all the anchor tags containing the URLs
    anchors = soup.find_all('a', href=True)

    # Extract the URLs of the real estate listings
    for anchor in anchors:
        href = anchor['href']
        if href.startswith('/annonces.cfm?pdtid='):
            listing_url = 'https://www.voursa.com' + href

            # Send an HTTP GET request to the real estate URL and retrieve the HTML content
            real_estate_response = requests.get(listing_url)
            real_estate_html = real_estate_response.content

            # Create a BeautifulSoup object to parse the real estate HTML content
            real_estate_soup = BeautifulSoup(real_estate_html, 'html.parser')

            # Extract the surface and description from the real estate page
            details_category = real_estate_soup.find('div', id='details_category')
            if details_category:
                surface_element = details_category.find('span', string='Surface(m²):')
                surface_value = surface_element.find_next_sibling('span', class_='valued').text.strip() if surface_element else 'N/A'
                description_element = real_estate_soup.find('div', id='pdesc')
                description_text = description_element.text.strip() if description_element else 'N/A'

                # Clean the description text
                description_text = description_text.replace('Description: \r\n', '')

                additional_info_element = real_estate_soup.find('span', class_='StylH2')
                additional_info_text = additional_info_element.get_text(strip=True) if additional_info_element else 'N/A'

                # Check if additional info contains any of the keywords
                if any(keyword in additional_info_text for keyword in keywords):
                    telephone_element = real_estate_soup.find('div', id='nom')
                    telephone_text = telephone_element.find('div', id='vendinfo').text.strip() if telephone_element else 'N/A'

                    # Extract telephone number using regular expressions
                    telephone_number = re.search(r'Téléphones:\s+(\d+ \d+ \d+ \d+)', telephone_text)
                    telephone_number = telephone_number.group(1) if telephone_number else 'N/A'

                    price_element = real_estate_soup.find('div', id='prix')
                    price_text = price_element.text.strip() if price_element else 'N/A'

                    surface.append(surface_value)
                    description.append(description_text)
                    additional_info.append(additional_info_text)
                    telephone_numbers.append(telephone_number)
                    prices.append(price_text)
            else:
                surface_value = 'N/A'
                description_text = 'N/A'
                additional_info_text = 'N/A'
                telephone_number = 'N/A'
                price_text = 'N/A'

# Create a DataFrame from the scraped data
data = {
    'Surface': surface,
    'Description': description,
    'Additional Info': additional_info,
    'Telephone Number': telephone_numbers,
    'Price': prices
}
df17 = pd.DataFrame(data)

# Save the DataFrame to a CSV file
# df.to_csv('real_estate_data.csv', index=False, encoding='utf-8-sig')

# Print the DataFrame
df17.head(10)
# Out:
#   Surface                                        Description Additional Info  \
# 0     N/A      فيلا في تفرغ زينة راقية و مؤثثة اثاث راقي ...  Maison - Villa
# 1     N/A      A vendre une villa neuf tres haut standing...  Maison - Villa
# 2     N/A                                        للجادين فقط        Bâtiment
# 3     N/A                          للجادين فقط اوراقها تامين  Maison - Villa
# 4     N/A      الموقع عن كرفور كدروه كرفات الرسمي وكدروه ...  Maison - Villa
# 5     N/A      للجاديه هذي دار جديده ومكفله تكفال زين وعل...  Maison - Villa
# 6     N/A                                   أحذبقالة طين طان  Maison - Villa
# 7     N/A      دار لتنسويلم عل شارع الطب قريب من كدروه ال...  Maison - Villa
# 8     N/A      سلام عليكم و رحمة الله تعالى و بركاته عندي...  Maison - Villa
# 9     N/A                 فاتح اعل ابديه اصغير قريه من كدروه  Maison - Villa
#
#   Telephone Number             Price
# 0      41 30 60 60  prix indéterminé
# 1      36 68 43 68  prix indéterminé
# 2      44 04 38 70     8,500,000 MRU
# 3      44 04 38 70    14,000,000 MRU
# 4      44 04 38 70    42,000,000 MRU
# 5      44 04 38 70       580,000 MRU
# 6      47 97 86 12     1,200,000 MRU
# 7      41 13 71 85  prix indéterminé
# 8      37 10 10 70     3,400,000 MRU
# 9      46 23 72 32     1,050,000 MRU

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define the base URL of the real estate website
base_url = 'https://www.voursa.com/Index.cfm?PN={}&gct=3&gv=13'

# Set the number of pages to scrape (modify as per your requirement)
num_pages = 279

# Initialize empty lists to store the scraped data
surface = []
description = []
additional_info = []
telephone_numbers = []
prices = []

# Define the keywords to filter by
keywords = ['Maison', 'Bâtiment', 'Villa']

# Iterate over each page
for page in range(271, num_pages + 1):
    # Construct the URL for the current page
    url = base_url.format(page)

    # Send an HTTP GET request to the website and retrieve the HTML content
    response = requests.get(url)
    html_content = response.content

    # Create a BeautifulSoup object to parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find all the anchor tags containing the URLs
    anchors = soup.find_all('a', href=True)

    # Extract the URLs of the real estate listings
    for anchor in anchors:
        href = anchor['href']
        if href.startswith('/annonces.cfm?pdtid='):
            listing_url = 'https://www.voursa.com' + href

            # Send an HTTP GET request to the real estate URL and retrieve the HTML content
            real_estate_response = requests.get(listing_url)
            real_estate_html = real_estate_response.content

            # Create a BeautifulSoup object to parse the real estate HTML content
            real_estate_soup = BeautifulSoup(real_estate_html, 'html.parser')

            # Extract the surface and description from the real estate page
            details_category = real_estate_soup.find('div', id='details_category')
            if details_category:
                surface_element = details_category.find('span', string='Surface(m²):')
                surface_value = surface_element.find_next_sibling('span', class_='valued').text.strip() if surface_element else 'N/A'
                description_element = real_estate_soup.find('div', id='pdesc')
                description_text = description_element.text.strip() if description_element else 'N/A'

                # Clean the description text
                description_text = description_text.replace('Description: \r\n', '')

                additional_info_element = real_estate_soup.find('span', class_='StylH2')
                additional_info_text = additional_info_element.get_text(strip=True) if additional_info_element else 'N/A'

                # Check if additional info contains any of the keywords
                if any(keyword in additional_info_text for keyword in keywords):
                    telephone_element = real_estate_soup.find('div', id='nom')
                    telephone_text = telephone_element.find('div', id='vendinfo').text.strip() if telephone_element else 'N/A'

                    # Extract telephone number using regular expressions
                    telephone_number = re.search(r'Téléphones:\s+(\d+ \d+ \d+ \d+)', telephone_text)
                    telephone_number = telephone_number.group(1) if telephone_number else 'N/A'

                    price_element = real_estate_soup.find('div', id='prix')
                    price_text = price_element.text.strip() if price_element else 'N/A'

                    surface.append(surface_value)
                    description.append(description_text)
                    additional_info.append(additional_info_text)
                    telephone_numbers.append(telephone_number)
                    prices.append(price_text)
            else:
                surface_value = 'N/A'
                description_text = 'N/A'
                additional_info_text = 'N/A'
                telephone_number = 'N/A'
                price_text = 'N/A'

# Create a DataFrame from the scraped data
data = {
    'Surface': surface,
    'Description': description,
    'Additional Info': additional_info,
    'Telephone Number': telephone_numbers,
    'Price': prices
}
df18 = pd.DataFrame(data)

# Save the DataFrame to a CSV file
# df.to_csv('real_estate_data.csv', index=False, encoding='utf-8-sig')

# Print the DataFrame
df18.head(10)
# Out:
#   Surface                                        Description Additional Info  \
# 0     N/A      A vendre une villa neuf tres haut standing...  Maison - Villa
# 1     N/A      فيلا في تفرغ زينة راقية و مؤثثة اثاث راقي ...  Maison - Villa
# 2     N/A      فيلا للبيع في تفرغ زينة (أفنور) بالقرب من ...  Maison - Villa
# 3     N/A      فيلا للبيع في تفرغ زينة الصحراوي أجديده لل...  Maison - Villa
# 4     N/A      منزل في ابيكة 10 قريب من كدروه روصولمزيد م...  Maison - Villa
# 5     N/A                              Maison 12×13m2.arafat  Maison - Villa
# 6     N/A      المنزل المذكور فيه صلوه وبيت اركاد وبيت او...  Maison - Villa
# 7     N/A      الدار أجديده ماك اندخلت افكرن اوفاتح على ش...  Maison - Villa
# 8     N/A      الدار عند كرفور اسطمبول مساحته 15 m اف 10m...  Maison - Villa
# 9     N/A      علان                                   عن ...  Maison - Villa
#
#   Telephone Number             Price
# 0      36 68 43 68  prix indéterminé
# 1      41 30 60 60  prix indéterminé
# 2      22 36 64 31     3,500,000 MRU
# 3      22 36 64 31     3,200,000 MRU
# 4      20 02 25 09  prix indéterminé
# 5      27 65 98 20  prix indéterminé
# 6      27 41 89 49  prix indéterminé
# 7      37 30 00 58     2,300,000 MRU
# 8      42 66 70 66  prix indéterminé
# 9      37 38 18 18       250,000 MRU

# %%
import pandas as pd

# Create a list to store all the dataframes
dfs = []

# Load the first dataframe named 'df'
df = globals()['df']  # Assuming you have already defined the 'df' dataframe
dfs.append(df)

# Iterate over the remaining dataframe names and load them into the list
for i in range(1, 19):
    df_name = 'df' + str(i)
    df = globals()[df_name]  # Assuming you have already defined the dataframes
    dfs.append(df)

# Concatenate all the dataframes into a single dataframe
merged_df = pd.concat(dfs)

# Remove duplicates and keep only unique values
unique_df = merged_df.drop_duplicates()

# Reset the index of the new dataframe
unique_df = unique_df.reset_index(drop=True)

# Save the dataframe to a CSV file with utf-8 encoding
unique_df.to_csv('voursa_real_estate_info.csv', index=False, encoding='utf-8-sig')

# %%
unique_df.describe()
# Out:
#        Surface                                        Description  \
# count     5046                                               5046
# unique       1                                               4918
# top        N/A      يمكنكم التواصل معنا عبر الواتساب علي الرقم...
# freq      5046                                                 21
#
#        Additional Info Telephone Number             Price
# count             5046             5046              5046
# unique               2             1168               326
# top     Maison - Villa      31 06 45 08  prix indéterminé
# freq              4573              518               539

# %%
code="Wwh8Tg-daseMIQPvUydAq-2o2J97L1tYuSDdP9mrsfkXSmm1XDrnuckSBaVVa1J4tGPYyw."

# %%
description = "دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293"

description_list = [description] * 10

# Print the list
print(description_list)
# Out:
# ['دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293', 'دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293']

# %%
from bardapi import Bard
import pandas as pd
token =code # 'xxxxxxx'
bard = Bard(token=token)

# Iterate over the descriptions
for description in description_list[:10]:  # Modify the range to select the desired number of descriptions
    bard.get_answer(f"extract House address, Price, Salon, Room, Sitting area, Gathering room, Storage room, Kitchen, Public bathroom, Worker's house, Small storage room, Garage, Number of rooms [based on the features specified], Phone number from the following text: {description}")
    bard.get_answer("yes you can do it")
    bard.get_answer("into json please")

# %%
from bardapi import Bard
import pandas as pd
token =code # 'xxxxxxx'
bard = Bard(token=token)

# Extract features from the Description column of unique_df
description_list = unique_df['Description'].tolist()
features_list = []

# Iterate over the descriptions
for description in description_list:
    response = bard.get_answer(f"extract House address, Price, Salon, Room, Sitting area, Gathering room, Storage room, Kitchen, Public bathroom, Worker's house, Small storage room, Garage, Number of rooms [based on the features specified], Phone number from the following text: {description}")
    response = bard.get_answer("yes you can do it")
    response = bard.get_answer("into json please")

    # Extract the features from the response
    choices = response['choices']
    for choice in choices:
        content = choice['content'][0]
        if '**Features:**' in content:
            feature_list = content.split('**Features:**')[1].strip().split('\n')
            features_list.extend(feature_list)

# Create a DataFrame with the extracted features
df_features = pd.DataFrame(features_list, columns=['Feature'])

# Print the DataFrame
df_features.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [52], in <cell line: 11>()
#      11 for description in description_list:
#      12     response = bard.get_answer(f"extract House address, Price, Salon, Room, Sitting area, Gathering room, Storage room, Kitchen, Public bathroom, Worker's house, Small storage room, Garage, Number of rooms [based on the features specified], Phone number from the following text: {description}")
# ---> 13     response = bard.get_answer("yes you can do it")
#      14     response = bard.get_answer("into json please")
#      16     # Extract the features from the response
#
# File ~\anaconda3\lib\site-packages\bardapi\core.py:106, in Bard.get_answer(self, input_text)
#      97 input_text_struct = [
#      98     [input_text],
#      99     None,
#     100     [self.conversation_id, self.response_id, self.choice_id],
#     101 ]
#     102 data = {
#     103     "f.req": json.dumps([None, json.dumps(input_text_struct)]),
#     104     "at": self.SNlM0e,
#     105 }
# --> 106 resp = self.session.post(
#     107     "https://bard.google.com/_/BardChatUi/data/assistant.lamda.BardFrontendService/StreamGenerate",
#     108     params=params,
#     109     data=data,
#     110     timeout=self.timeout,
#     111     proxies=self.proxies,
#     112 )
#     113 resp_dict = json.loads(resp.content.splitlines()[3])[0][2]
#     115 if not resp_dict:
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:577, in Session.post(self, url, data, json, **kwargs)
#     566 def post(self, url, data=None, json=None, **kwargs):
#     567     r"""Sends a POST request. Returns :class:`Response` object.
#     568
#     569     :param url: URL for the new :class:`Request` object.
#    (...)
#     574     :rtype: requests.Response
#     575     """
# --> 577     return self.request('POST', url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
from bardapi import Bard

# Set up Bard API
token =code # 'xxxxxxx'
bard = Bard(token=token)

# Read the CSV file
df = pd.read_csv('voursa_real_estate_info.csv')

# Select a subset of the data for testing (e.g., first 10 or 20 rows)
subset = df.head(20)  # Adjust the number of rows as needed

# Extract features from the Description column
extracted_features = []
for description in subset['Description']:
    response = bard.get_answer(description)
    features = response['content']
    extracted_features.append(features)

# Create a new DataFrame with the extracted features
extracted_df = pd.DataFrame({'Description': subset['Description'], 'Extracted Features': extracted_features})

# Save the extracted features to a new CSV file
extracted_df.to_csv('voursa_real_estate_info_extracted.csv', index=False, encoding='utf-8-sig')

# %%
extracted_df.head()
# Out:
#                                          Description  \
# 0      A vendre une villa neuf tres haut standing...
# 1      فيلا في تفرغ زينة راقية و مؤثثة اثاث راقي ...
# 2      فيلا للبيع في تفرغ زينة (أفنور) بالقرب من ...
# 3      فيلا للبيع في تفرغ زينة الصحراوي أجديده لل...
# 4      منزل في ابيكة 10 قريب من كدروه روصولمزيد م...
#
#                                   Extracted Features
# 0  I do not have enough information about that pe...
# 1  Sure, I can help you with that.\n\nThe text yo...
# 2  I'm still learning languages, so at the moment...
# 3  As an LLM, I am trained to understand and resp...
# 4  I'm still learning languages, so at the moment...

# %%
from bardapi import Bard

# Set up Bard API
token = code # 'xxxxxxx'
bard = Bard(token=token)

# Select a single line from the DataFrame
line = df.loc[0, 'Description']  # Replace '0' with the desired row index

# Extract features from the description
response = bard.get_answer(line)
features = response['content']

# Print the extracted features
print(features)
# Out:
# Sure, I can help you with that. Here is the translation of the text you provided:
#
# * **French:** A vendre une villa neuf tres haut standing situe à Trab Didi ould Souedi, a Tevragh Zeina.Pour plus d'info veuillez me rejoindre.Merci
# * **English:** For sale, a new villa with very high standards located in Trab Didi ould Souedi, in Tevragh Zeina. For more information, please contact me. Thank you.
# * **Arabic:** للبيع فيلا جديدة بمواصفات عالية و راقية للمزيد من المعلومات يرجي الاتصال بي
#
# The text is an advertisement for a new villa for sale in Tevragh Zeina. The villa is located in a high-end area and has high-quality finishes. The ad does not specify the price of the villa, but it encourages interested buyers to contact the seller for more information.
#
# I hope this is helpful! Let me know if you have any other questions.

# %%
from bardapi import Bard

# Set up Bard API
token = code # 'xxxxxxx'
bard = Bard(token=token)
text = "دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز للبيع دار ارضيه نظيفه فتوجنين الحي الإداري موقعه ممتاز جدا فيه صالونه وبيت ارگاد وجلسة وبيت اجماعه ومگزينه ومبطبخ وحمام عمومي وبيت للعامل و تحويشه اسغيره واگراج للبيع ب 12 مليون اوقيه قديمه للاستفسار يرجى الاتصال او الواتساب على الرقم 36119293"
bard.get_answer(text)['content']
# Out:
# "I am still working to learn more languages, so I can't do that just yet. Please refer to the Bard Help Center for a current list of supported languages. Is there anything else you'd like my help with?"

# %%
bard.get_answer(text)['content']
bard.get_answer("yes you can do it")['content']
Output-bard_getanswer("into json")['content']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 3>()
#       1 bard.get_answer(text)['content']
#       2 bard.get_answer("yes you can do it")['content']
# ----> 3 Output-bard_getanswer("into json")['content']
#
# NameError: name 'Output' is not defined

# %%
126598743
# Out:
# 126598743
